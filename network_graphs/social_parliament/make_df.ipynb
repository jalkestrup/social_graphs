# %%
#import json file sample_json.json

import json
with open('clean_sager.json') as f:
    data_folketing = json.load(f)

#import clean_sager.pickle using pickle


import pandas as pd
import numpy as np


import pandas as pd
def voting_df(data):
    df = pd.DataFrame()

    df['afstemnings_id'] = [x['id'] for x in data]
    df['sagstrin_id'] = [x['sagstrinid'] for x in data]
    df['vedtaget'] = [x['vedtaget'] for x in data]
    df['dato'] = [x['opdateringsdato'] for x in data]
    df['sag_id'] = [x['Sagstrin']['Sag']['id'] for x in data]
    df['titel']= [x['Sagstrin']['Sag']['titel'] for x in data]
    df['titel_kort'] = [x['Sagstrin']['Sag']['titelkort'] for x in data]
    df['lovnummer_num'] = [x['Sagstrin']['Sag']['nummernumerisk'] for x in data]
    df['lovnummer'] = [x['Sagstrin']['Sag']['nummer'] for x in data]
    df['resume']= [x['Sagstrin']['Sag']['resume'] for x in data]
    df['periode_id']= [x['Sagstrin']['Sag']['periodeid'] for x in data]

    return df
    

        
df = voting_df(data_folketing)
df.head()
# Out:
#    afstemnings_id  sagstrin_id  vedtaget                     dato  sag_id  \
# 0               2         4849      True  2014-09-09T09:25:05.717    1449
# 1               3        17351      True   2018-01-24T16:46:33.99    5604
# 2               4        18370      True   2018-01-25T10:25:25.64    5904
# 3               5         4849      True   2017-08-10T12:57:52.27    1449
# 4               6        16581      True  2017-08-10T12:57:52.257    5384
#
#                                                titel  \
# 0  Forslag til lov om ændring af virksomhedsskatt...
# 1  Folketinget konstaterer, at Danmark stod dårli...
# 2  Forslag til lov om akutjob og jobpræmie til ar...
# 3  Forslag til lov om ændring af virksomhedsskatt...
# 4  Forslag til folketingsbeslutning om dansk mili...
#
#                                           titel_kort lovnummer_num lovnummer  \
# 0  Om indgreb mod utilsigtet udnyttelse af virkso...           200     L 200
# 1                                Om rigets tilstand.             2       V 2
# 2                                        Om akutjob.            46      L 46
# 3  Om indgreb mod utilsigtet udnyttelse af virkso...           200     L 200
# 4  Om dansk militært bidrag til støtte for indsat...           122     B 122
#
#                                               resume  periode_id
# 0  Loven ændrer virksomhedsskatteordningens regle...          32
# 1                                                             31
# 2  Med loven etableres en midlertidig ordning, så...          31
# 3  Loven ændrer virksomhedsskatteordningens regle...          32
# 4  Med folketingsbeslutningen giver Folketinget s...          32
